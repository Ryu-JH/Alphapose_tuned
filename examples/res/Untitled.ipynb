# %%
import json

# %%
with open('vis/alphapose-results.json', 'r') as f:
    json_data = json.load(f)

# %%
json_data[0]['keypoints']
# Out:
# [279.6434631347656,
#  199.90963745117188,
#  0.9273797869682312,
#  284.6189880371094,
#  184.98309326171875,
#  0.9254390597343445,
#  269.6924133300781,
#  184.98309326171875,
#  0.9594348073005676,
#  279.6434631347656,
#  184.98309326171875,
#  0.4129640758037567,
#  219.93724060058594,
#  189.95860290527344,
#  0.9633684158325195,
#  244.81483459472656,
#  254.64035034179688,
#  0.7083401679992676,
#  205.01068115234375,
#  279.5179443359375,
#  0.7905341386795044,
#  264.7169189453125,
#  334.2486267089844,
#  0.8266342878341675,
#  224.9127655029297,
#  433.7590026855469,
#  0.917720377445221,
#  344.3251953125,
#  354.1507263183594,
#  0.6936041712760925,
#  339.34967041015625,
#  458.6365966796875,
#  0.8424366116523743,
#  304.52105712890625,
#  393.9548645019531,
#  0.6798434257507324,
#  289.5945129394531,
#  443.7100524902344,
#  0.5650793313980103,
#  428.9090270996094,
#  374.05279541015625,
#  0.8524425625801086,
#  458.7621154785156,
#  433.7590026855469,
# ...

# %%
json_data['score']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-4cb1a0c5e336> in <module>()
# ----> 1 json_data['score']
#
# TypeError: list indices must be integers or slices, not str

# %%
len(json_data)
# Out:
# 4101

# %%
for i in range(len(json_data)):
    if len(json_data[i]['keypoints']) == 51:
        pass
    else:
        print(len(json_data[i]['keypoints']))

# %%
for i in range(len(json_data)):
    print(i, json_data[i]['score'])
# Out:
# 0 2.857186794281006
# 1 2.7650094032287598
# 2 2.724790573120117
# 3 2.7331204414367676
# 4 2.748185634613037
# 5 2.815356731414795
# 6 2.830427408218384
# 7 2.7103939056396484
# 8 2.7053780555725098
# 9 2.7200801372528076
# 10 2.7670135498046875
# 11 2.7303519248962402
# 12 2.6093599796295166
# 13 2.6221463680267334
# 14 2.6663460731506348
# 15 2.1609954833984375
# 16 2.687828540802002
# 17 2.6644744873046875
# 18 2.679189682006836
# 19 2.670145034790039
# 20 2.665776252746582
# 21 2.7071733474731445
# 22 2.698917865753174
# 23 2.691925287246704
# 24 2.6422176361083984
# 25 2.6540441513061523
# 26 2.626516580581665
# 27 2.2430601119995117
# 28 2.678075075149536
# 29 2.595357894897461
# 30 2.621218204498291
# 31 2.6393749713897705
# 32 2.669719696044922
# 33 2.6937484741210938
# 34 2.7087011337280273
# 35 2.7984352111816406
# 36 2.8049299716949463
# 37 2.8197526931762695
# 38 2.9069786071777344
# 39 2.8438310623168945
# 40 2.8541676998138428
# 41 2.7468676567077637
# ...

# %%
json_data[2893]['keypoints']
# Out:
# [441.6340637207031,
#  268.6905212402344,
#  0.37469860911369324,
#  441.6340637207031,
#  263.9164123535156,
#  0.35151228308677673,
#  427.31170654296875,
#  263.9164123535156,
#  0.4450955390930176,
#  484.60113525390625,
#  285.39996337890625,
#  0.11162057518959045,
#  403.44110107421875,
#  275.8517150878906,
#  0.2573201358318329,
#  446.4081726074219,
#  323.5928955078125,
#  0.09471742808818817,
#  441.6340637207031,
#  333.1411437988281,
#  0.0984480008482933,
#  546.6646728515625,
#  354.6246643066406,
#  0.07765287905931473,
#  527.5681762695312,
#  373.7211608886719,
#  0.07626740634441376,
#  410.6022644042969,
#  304.4964294433594,
#  0.12965890765190125,
#  415.37640380859375,
#  304.4964294433594,
#  0.3041892349720001,
#  568.148193359375,
#  366.5599670410156,
#  0.04467429593205452,
#  544.277587890625,
#  385.6564636230469,
#  0.054623328149318695,
#  568.148193359375,
#  325.9799499511719,
#  0.13124790787696838,
#  546.6646728515625,
#  364.17291259765625,
# ...
